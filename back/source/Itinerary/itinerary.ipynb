# %%
import os
import numpy as np
import pandas as pd
from pprint import pprint
from slugify import slugify


def open_dataset(file_name):
    return pd.read_csv(filepath_or_buffer=file_name, delimiter="\t", encoding="utf-8", header=0)


itineraries = open_dataset('../../data_sncf/timetables.csv')
itineraries = itineraries.sort_values(
    by=['trip_id', 'trajet', 'duree'], ascending=[True, True, True])

# dataframe refacto
trajet_splited = itineraries['trajet'].str.split(' - ')

for key, values in trajet_splited.iteritems():
    trajet_splited[key] = [slugify(x) for x in trajet_splited[key]]

itineraries['start'] = trajet_splited.str[0]
itineraries['end'] = trajet_splited.str[1]

itineraries.drop('trajet', axis=1, inplace=True)
itineraries.drop('trip_id', axis=1, inplace=True)

# inverse start & end
itinerariesInversed = itineraries.rename(columns={'start': 'end', 'end': 'start'})
itineraries = pd.concat([itineraries, itinerariesInversed])

# remove duplicate on start/end
itineraries = itineraries.drop_duplicates(['start','end'], keep= 'last')
itineraries.head()
# Out:
#    duree                    start                        end
# 0    138         gare-de-le-havre    gare-de-paris-st-lazare
# 1    145           gare-de-dieppe    gare-de-paris-st-lazare
# 2     97  gare-de-paris-st-lazare  gare-de-rouen-rive-droite
# 3    194        gare-de-cherbourg    gare-de-paris-st-lazare
# 4    149             gare-de-caen    gare-de-paris-st-lazare

# %%
# Filter all possible localisations
locsStart = itineraries['start'].tolist()
locsEnd = itineraries['end'].tolist()
locs = list(dict.fromkeys(locsStart + locsEnd))
# len(locs)
locs
# Out:
# ['gare-de-le-havre',
#  'gare-de-dieppe',
#  'gare-de-paris-st-lazare',
#  'gare-de-cherbourg',
#  'gare-de-caen',
#  'gare-de-granville',
#  'gare-de-dreux',
#  'gare-de-bourges',
#  'gare-de-paris-austerlitz',
#  'gare-de-nevers',
#  'gare-de-argentan',
#  'gare-de-orleans',
#  'gare-de-aubrais-les',
#  'gare-de-paris-bercy',
#  'gare-de-calais-ville',
#  'gare-de-boulogne-ville',
#  'gare-de-amiens',
#  'gare-de-cambrai-ville',
#  'gare-de-maubeuge',
#  'gare-de-paris-gare-du-nord',
#  'gare-de-compiegne',
#  'gare-de-le-mans',
#  'gare-de-nogent-le-rotrou',
#  'gare-de-chartres',
#  'gare-de-blois-chambord',
#  'gare-de-lyon-perrache',
#  'gare-de-latour-de-carol-enveitg',
#  'gare-de-font-romeu-odeillo-via',
#  'gare-de-briancon',
#  'gare-de-romans-bourg-de-peage',
#  'gare-de-gap',
#  'gare-de-aix-en-provence',
#  'gare-de-marseille-st-charles',
#  'gare-de-les-arcs-draguignan',
#  'gare-de-grenoble',
#  'gare-de-chambery-chal-les-eaux',
#  'gare-de-annecy',
#  'gare-de-avignon-centre',
#  'gare-de-lyon-part-dieu',
#  'gare-de-dijon-ville',
#  'gare-de-macon-ville',
#  'gare-de-bourg-st-maurice',
#  'gare-de-albertville',
#  'gare-de-bourgoin-jallieu',
#  'gare-de-la-chaux-de-fonds',
#  'gare-de-besancon-viotte',
#  'gare-de-besancon-mouillere',
#  'gare-de-pontarlier',
#  'gare-de-frasne',
#  'gare-de-neuchatel',
#  'gare-de-dole-ville',
#  'gare-de-delemont',
#  'gare-de-delle',
#  'gare-de-biel',
#  'gare-de-aix-les-bains-le-revard',
#  'gare-de-st-gervais-l-b-le-fayet',
#  'gare-de-chamonix-mont-blanc',
#  'gare-de-aulnoye-aymeries',
#  'gare-de-courtrai-kortrijk',
#  'gare-de-lille-flandres',
#  'gare-de-brive-la-gaillarde',
#  'gare-de-le-creusot',
#  'gare-de-nice-ville',
#  'gare-de-breil-sur-roya',
#  'gare-de-annemasse',
#  'gare-de-decize',
#  'gare-de-coppet',
#  'gare-de-cluses-hte-savoie',
#  'gare-de-forbach',
#  'gare-de-bening',
#  'bitche',
#  'bitche-camp',
#  'gare-de-haguenau',
#  'bouxwiller-schattenmann',
#  'gare-de-saverne',
#  'gare-de-ingwiller',
#  'dossenheim-mairie',
#  'gare-de-obermodern',
#  'bouxwiller-babenhausen',
#  'gare-de-strasbourg',
#  'gare-de-benfeld',
#  'gare-de-colmar',
#  'buswiller-eglise',
#  'ettendorf-pl-de-l-ecol',
#  'ettendorf-angle-pont',
#  'gare-de-diemeringen',
#  'gare-de-sarreguemines',
#  'gare-de-lutzelbourg',
#  'gare-de-kruth',
#  'gare-de-cernay-haut-rhin',
#  'cernay-lycee',
#  'gare-de-basel-sbb',
#  'frohmuhl-lavoir',
#  'hattmatt-s-polyvalente',
#  'gare-de-herrlisheim-bas-rhin',
#  'gare-de-lauterbourg',
#  'gare-de-entzheim-aeroport',
#  'gare-de-barr',
#  'gare-de-molsheim',
#  'gare-de-rothau',
#  'gare-de-saales',
#  'gare-de-altkirch',
#  'gare-de-belfort-ville',
#  'gare-de-selestat',
#  'gare-de-st-die-des-vosges',
#  'ste-croix-mines-sq-de-g',
#  'ste-marie-mines-maire',
#  'liepvre-r-guth',
#  'ste-marie-ms-pl-cdg',
#  'gare-de-montlucon-ville',
#  'laqueuille',
#  'gare-de-clermont-ferrand',
#  'gare-de-gannat',
#  'gare-de-aurillac',
#  'gare-de-thiers',
#  'gare-de-arvant',
#  'gare-de-moulins-sur-allier',
#  'ancizes-st-georges-bour',
#  'gare-de-lapeyrouse-puy-de-dome',
#  'gare-de-volvic',
#  'gare-de-massiac-blesle',
#  'gare-de-riom-chatel-guyon',
#  'gare-de-neussargues',
#  'gare-de-st-chely-d-apcher',
#  'brioude-lycee-lafayette',
#  'gare-de-langeac',
#  'gare-de-brioude',
#  'gare-de-le-puy-en-velay',
#  'ambert',
#  'gare-de-pont-de-dore',
#  'gare-de-ussel',
#  'gare-de-vic-le-comte',
#  'gare-de-issoire',
#  'gare-de-luzy-nievre',
#  'gare-de-cercy-la-tour',
#  'gare-de-autun',
#  'chauffailles-gambetta',
#  'gare-de-digoin',
#  'gare-de-louhans',
#  'gare-de-bourg-en-bresse',
#  'gare-de-auxerre-st-gervais',
#  'gare-de-clamecy',
#  'gare-de-lorient',
#  'chateaubriant',
#  'gare-de-dinan',
#  'gare-de-valencay',
#  'gare-de-romorantin-blanc-argent',
#  'gare-de-faubourg-d-orleans',
#  'la-ferte-sur-chiers',
#  'gare-de-chalons-en-champagne',
#  'gare-de-st-dizier',
#  'gare-de-joinville',
#  'gare-de-chaumont',
#  'gare-de-bar-sur-aube',
#  'gare-de-troyes',
#  'bayel-eglise',
#  'gare-de-vendeuvre-aube',
#  'bricon-la-poste',
#  'gare-de-st-florentin-vergigny',
#  'gare-de-laroche-migennes',
#  'gare-de-romilly-sur-seine',
#  'gare-de-nogent-sur-seine',
#  'gare-de-charleville-mezieres',
#  'gare-de-fismes',
#  'gare-de-aillevillers',
#  'gare-de-le-locle',
#  'gare-de-le-valdahon',
#  'gare-de-lons-le-saunier',
#  'gare-de-mouchard',
#  'dompierre-halte-rout',
#  'gare-de-champagnole',
#  'gare-de-champagnole-pe-victor',
#  'gare-de-andelot',
#  'gare-de-ales',
#  'gare-de-la-bastide-st-laurent',
#  'gare-de-langogne',
#  'gare-de-millau',
#  'gare-de-mende',
#  'gare-de-carcassonne',
#  'gare-de-limoux',
#  'gare-de-bedarieux',
#  'gare-de-gueret',
#  'gare-de-tulle',
#  'gare-de-egletons',
#  'bort-les-orgues',
#  'gare-de-nancy-ville',
#  'martigny-les-b-thiebaut',
#  'damblain-eglise',
#  'gare-de-contrexeville',
#  'gare-de-vittel',
#  'bitche-quartier-driant',
#  'gare-de-charmes-vosges',
#  'igney-centre',
#  'gare-de-sarrebourg',
#  'gare-de-longuyon',
#  'gare-de-morhange',
#  'longuyon-college',
#  'fenetrange-gendarm',
#  'loudrefing',
#  'sarrebourg-place-math',
#  'sarrebourg-lp-messmer',
#  'gare-de-neufchateau',
#  'gare-de-toul',
#  'allamps-esat',
#  'creutzwald-g-r',
#  'gare-de-epinal',
#  'bruyeres-vosges',
#  'bouzonville',
#  'gare-de-thionville',
#  'corcieux-le-conti',
#  'gare-de-arches',
#  'bruyeres-chanzy-gare',
#  'herbitzheim-r-hambach',
#  'herbitzheim-mairie',
#  'berthelming-mairie',
#  'gare-de-metz-ville',
#  'keskastel',
#  'gare-de-bar-le-duc',
#  'gare-de-conflans-jarny',
#  'gare-de-figeac',
#  'gare-de-mazamet',
#  'gare-de-muret',
#  'gare-de-pau',
#  'gare-de-agen',
#  'gare-de-longages-noe',
#  'gare-de-montrejeau-gourdan-pol',
#  'gare-de-ax-les-thermes',
#  'gare-de-foix',
#  'gare-de-souillac',
#  'gare-de-albi-ville',
#  'comines-france',
#  'gare-de-abbeville',
#  'gare-de-lens',
#  'gare-de-avesnes',
#  'gare-de-arras',
#  'gare-de-hazebrouck',
#  'gare-de-busigny',
#  'gare-de-calais-frethun',
#  'gare-de-coutances',
#  'bagnoles-orne-egl-mad',
#  'gare-de-alencon',
#  'gare-de-l-aigle',
#  'gare-de-lisieux',
#  'gare-de-dives-cabourg',
#  'gare-de-villedieu-gare',
#  'gare-de-breaute-beuzeville',
#  'gare-de-mantes-la-jolie',
#  'pont-audemer-gare-sncf',
#  'rouen-gare-routiere',
#  'bourg-achard-champ-de-f',
#  'gare-de-nantes',
#  'gare-de-cholet',
#  'gare-de-albert',
#  'gare-de-beauvais-gare-sncf',
#  'gare-de-hirson',
#  'gare-de-chatellerault',
#  'gare-de-mauze',
#  'gare-de-niort',
#  'gare-de-bressuire',
#  'gare-de-la-roche-sur-yon',
#  'gare-de-valence-tgv',
#  'grenoble-gare-routiere',
#  'gare-de-st-andre-le-gaz',
#  'lyon-part-dieu-gare-rou',
#  'gare-de-lozanne',
#  'gare-de-lamure-sur-azergues',
#  'bois-d-oingt-centre',
#  'gare-de-die',
#  'gare-de-veynes-devoluy',
#  'gare-de-luc-en-diois',
#  'gare-de-evian-les-bains',
#  'saint-etienne-chtx-gr',
#  'gare-de-modane',
#  'annonay-gare-route',
#  'privas-cours-du-palais',
#  'gare-de-moutiers-salins-brides',
#  'gare-de-bonneville',
#  'aubenas-pl-de-la-paix',
#  'bourg-en-bresse-gare-r',
#  'gare-de-oyonnax',
#  'chamberry-jacob',
#  'montelimar-g-routiere',
#  'gare-de-saint-claude',
#  'gare-de-thonon-les-bains',
#  'gare-de-franois',
#  'gare-de-auxonne',
#  'gare-de-bellegarde-s-v-gare',
#  'gare-de-amberieu-en-bugey',
#  'gare-de-boen',
#  'gare-de-montbrison',
#  'noiretable',
#  'gare-de-clelles-mens',
#  'clelles-mairie',
#  'gare-de-vif',
#  'gare-de-sain-bel',
#  'lyon-perrache-gare-rout',
#  'argentine',
#  'gare-de-st-priest',
#  'gare-de-villefranche-sur-saone',
#  'gare-de-la-tour-du-pin',
#  'gare-de-feurs',
#  'gare-de-albens',
#  'gare-de-serezin',
#  'communay-stade',
#  'gare-de-epierre-st-leger',
#  'gare-de-st-jean-de-maurienne-a',
#  'aiton-salle-polyvalente',
#  'gare-de-chinon',
#  'chinon-lycee-rabelais',
#  'gare-de-tours',
#  'gare-de-chateau-du-loir',
#  'droue-centre',
#  'courtalain-centre',
#  'chartres-gare-routiere',
#  'gare-de-brou',
#  'gare-de-vendome',
#  'aubigny-sur-nere-mail',
#  'gare-de-gien',
#  'gare-de-cosne-sur-loire',
#  'bourges-gare-routiere',
#  'chateauroux-gare-rout',
#  'gare-de-vierzon',
#  'gare-de-issoudun',
#  'le-blanc-pl-du-bateau',
#  'gare-de-nouan-le-fuzelier',
#  'chaumont-sur-tharonne',
#  'gare-de-lamotte-beuvron',
#  'chateauroux-ly-b-pascal',
#  'chateauroux-lycee-agric',
#  'gare-de-thesee',
#  'romorantin-ba-g-r',
#  'gare-de-loches',
#  'buzancais',
#  'chatillon-mail',
#  'clion-sur-indre',
#  'gare-de-cormery',
#  'chambourg-chopin',
#  'loches-lycee-st-denis',
#  'gare-de-esvres',
#  'gare-de-la-douzillere',
#  'loches-lep',
#  'gare-de-chateaudun',
#  'chateaudun-lep-paulsen',
#  'gare-de-chateau-renault',
#  'gare-de-luneville',
#  'luneville-lp',
#  'luneville-cite-scolai',
#  'gare-de-remiremont',
#  'gare-de-longwy',
#  'bussang-gare-sncf',
#  'bresse-claudel-la',
#  'gare-de-audun-le-roman',
#  'gare-de-marle-sur-serre',
#  'barentona-cel',
#  'barenton-sur-serre',
#  'gare-de-neustadt-weinstr-hbf',
#  'gare-de-winden-pfalz',
#  'gare-de-landau-pfalz-hbf',
#  'gare-de-fougeres',
#  'gare-de-grasse',
#  'gare-de-menton',
#  'gare-de-cannes-la-bocca',
#  'gare-de-monaco-monte-carlo',
#  'gare-de-cannes',
#  'gare-de-saarbrucken-sarrebruck',
#  'gare-de-mommenheim',
#  'gare-de-luxembourg',
#  'gare-de-perpignan',
#  'gare-de-narbonne',
#  'gare-de-nimes',
#  'gare-de-port-bou',
#  'gare-de-montpellier-saint-roch',
#  'gare-de-offenburg',
#  'gare-de-kehl',
#  'gare-de-mulhouse',
#  'gare-de-freiburg-breisgau',
#  'gare-de-bettembourg',
#  'gare-de-geneve',
#  'gare-de-st-pierre-des-corps',
#  'gare-de-roeschwoog',
#  'gare-de-thann-saint-jacques',
#  'gare-de-erstein',
#  'gare-de-bayonne',
#  'gare-de-mont-de-marsan',
#  'gare-de-bordeaux-st-jean',
#  'gare-de-lesparre',
#  'gare-de-dax',
#  'gare-de-arcachon',
#  'gare-de-condat-le-lardin',
#  'gare-de-bedous',
#  'gare-de-oloron-ste-marie',
#  'gare-de-bidos',
#  'gare-de-bergerac',
#  'gare-de-libourne',
#  'gare-de-commentry',
#  'gare-de-firminy',
#  'gare-de-dijon-porte-neuve',
#  'gare-de-avallon',
#  'gare-de-chagny',
#  'gare-de-besancon-franche-comte',
#  'gare-de-rennes',
#  'gare-de-montauban-de-bretagne',
#  'gare-de-messac-guipry',
#  'gare-de-redon',
#  'gare-de-besle',
#  'gare-de-brest',
#  'gare-de-landerneau',
#  'gare-de-lannion',
#  'gare-de-guingamp',
#  'gare-de-carhaix',
#  'gare-de-port-de-piles',
#  'gare-de-chateauroux',
#  'gare-de-argenton-sur-creuse',
#  'gare-de-port-boulet',
#  'gare-de-reims',
#  'gare-de-rethel',
#  'gare-de-laon',
#  'gare-de-dormans',
#  'gare-de-culmont-chalindrey',
#  'gare-de-cerbere',
#  'gare-de-le-grau-du-roi',
#  'gare-de-castelnaudary',
#  'gare-de-marvejols',
#  'gare-de-le-dorat',
#  'gare-de-limoges-benedictins',
#  'gare-de-st-yrieix-la-perche',
#  'gare-de-nexon',
#  'gare-de-objat',
#  'gare-de-baroncourt',
#  'gare-de-hagondange',
#  'gare-de-liverdun',
#  'gare-de-castres',
#  'gare-de-capdenac',
#  'gare-de-auch',
#  'gare-de-l-isle-jourdain-gers',
#  'gare-de-colomiers',
#  'gare-de-cahors',
#  'gare-de-boussens',
#  'gare-de-lourdes',
#  'gare-de-douai',
#  'gare-de-jeumont',
#  'gare-de-charleroi-sud',
#  'gare-de-dunkerque',
#  'gare-de-angers-st-laud',
#  'gare-de-connerre-beille',
#  'gare-de-laval',
#  'gare-de-tergnier',
#  'gare-de-creil',
#  'gare-de-st-quentin',
#  'gare-de-abancourt',
#  'gare-de-angouleme',
#  'gare-de-la-rochelle-ville',
#  'gare-de-la-rochelle-pt-dauphine',
#  'aix-gare-routiere',
#  'roanne-gare-routiere',
#  'gare-de-la-roche-sur-foron',
#  'gare-de-chedde',
#  'gare-de-krimmeri-meinau',
#  'gare-de-obernai',
#  'gare-de-lutterbach-tram-train',
#  'gare-de-mulhouse-gare-centrale',
#  'gare-de-niederbronn',
#  'gare-de-epernay',
#  'gare-de-paris-est',
#  'gare-de-champagne-ardenne',
#  'gare-de-chateau-thierry',
#  'gare-de-longueville-s-et-m',
#  'gare-de-bethune',
#  'gare-de-lille-europe',
#  'gare-de-clermont-de-l-oise',
#  'gare-de-crepy-en-valois',
#  'gare-de-oissel',
#  'gare-de-fecamp',
#  'gare-de-elbeuf-st-aubin',
#  'gare-de-rouen-rive-droite',
#  'gare-de-bueil',
#  'gare-de-evreux',
#  'gare-de-dol',
#  'gare-de-janze',
#  'gare-de-montreuil-sur-ille',
#  'gare-de-callac',
#  'gare-de-la-brohiniere',
#  'gare-de-quimper',
#  'gare-de-le-croisic',
#  'gare-de-les-sables-d-olonne',
#  'gare-de-chantonnay',
#  'gare-de-ancenis',
#  'gare-de-chateaubriant-tt',
#  'gare-de-clisson',
#  'gare-de-saumur',
#  'gare-de-thouars',
#  'gare-de-reignac',
#  'gare-de-paris-gare-de-lyon',
#  'gare-de-blere-la-croix',
#  'gare-de-st-aignan-noyers',
#  'gare-de-salbris',
#  'gare-de-poitiers',
#  'gare-de-royan',
#  'gare-de-mussidan',
#  'gare-de-le-buisson',
#  'gare-de-monsempron-libos',
#  'gare-de-macau',
#  'gare-de-biganos-facture',
#  'gare-de-eymoutiers-vassiviere',
#  'gare-de-felletin-gare',
#  'gare-de-perigueux',
#  'gare-de-la-souterraine',
#  'gare-de-rodez',
#  'gare-de-carmaux',
#  'gare-de-tessonnieres',
#  'gare-de-pamiers',
#  'gare-de-montauban-ville-bourbon',
#  'gare-de-st-sulpice-tarn',
#  'gare-de-tarbes',
#  'gare-de-st-germain-des-fosses',
#  'gare-de-lunel',
#  'gare-de-beziers',
#  'gare-de-genolhac',
#  'gare-de-avignon-tgv',
#  'gare-de-cavaillon',
#  'gare-de-gardanne',
#  'gare-de-manosque-greoux',
#  'gare-de-aubagne',
#  'gare-de-antibes',
#  'gare-de-hyeres',
#  'gare-de-carnoules',
#  'gare-de-grenoble-u-gieres',
#  'gare-de-st-marcellin',
#  'gare-de-givors-ville',
#  'gare-de-roanne',
#  'gare-de-vienne',
#  'gare-de-bas-monistrol',
#  'gare-de-lyon-st-paul',
#  'gare-de-l-arbresle',
#  'gare-de-brignais',
#  'gare-de-montereau',
#  'gare-de-corbigny',
#  'gare-de-chalon-sur-saone',
#  'gare-de-is-sur-tille',
#  'gare-de-etang',
#  'gare-de-montchanin',
#  'gare-de-trouville-deauville',
#  'gare-de-paris-montp-3-vaug',
#  'gare-de-paris-montparnasse-1-2',
#  'gare-de-villefranche-vernet-l-b',
#  'gare-de-valence-ville',
#  'gare-de-sens',
#  'gare-de-morteau',
#  'gare-de-vallorbe-cff',
#  'gare-de-travers',
#  'gare-de-meroux',
#  'gare-de-vallorcine',
#  'gare-de-mons',
#  'gare-de-namur',
#  'gare-de-tournai',
#  'gare-de-tende',
#  'gare-de-wissembourg',
#  'haguenau-moulin-neuf',
#  'niedermodern-uberach',
#  'saverne-ht-barr',
#  'neuwiller-r-bouxwiller',
#  'pfaffenhoffen-mairie',
#  'gare-de-raedersheim',
#  'gare-de-wingen-sur-moder',
#  'reipertswiller-sp',
#  'lichtenberg-eglise',
#  'thann-arret-la-poste',
#  'gare-de-thann',
#  'gare-de-wesserling',
#  'gare-de-metzeral',
#  'sewen-eglise',
#  'saverne-lycee-verne',
#  'saverne-pl-dragons',
#  'gare-de-montreux-vieux',
#  'ribeauville-gare-routie',
#  'riquewihr-poste',
#  'ste-marie-ms-theatre',
#  'selestat-schwilgue',
#  'selestat-schweisguth',
#  'liepvre-rte-vancelle',
#  'le-mont-dore-gare',
#  'gare-de-st-denis-pres-martel',
#  'gare-de-vichy',
#  'urcay-hotel-du-lyon-d-o',
#  'gare-de-st-amand-montrond-orval',
#  'gare-de-vertaizon',
#  'st-eloy',
#  'st-eloy-les-mines-lycee',
#  'st-gervais-mairie',
#  'le-mont-dore-ski',
#  'st-flour-les-allees',
#  'mauriac-lycee-cortat',
#  'mauriac',
#  'st-gervais-ch-lpa',
#  'riom-es-m-la-poste',
#  'gare-de-st-flour-chaudes-aigues',
#  'pontgibaud-ville',
#  'gare-de-st-georges-d-aurac',
#  'st-george-d-aurac-bourg',
#  'la-chaise-dieu',
#  'issoire-lycee-deville',
#  'le-breuil-sur-couze-lyc',
#  'gare-de-st-pierre-le-moutier',
#  'gare-de-paray-le-monial',
#  'gare-de-seurre',
#  'gare-de-quimperle',
#  'gare-de-retiers',
#  'lucay-le-male',
#  'sedan-place-calonne',
#  'gare-de-verdun',
#  'gare-de-vitry-le-francois',
#  'langres-gendarmerie',
#  'juvancourt',
#  'ville-sous-la-ferte',
#  'payns-abri-savieres',
#  'gare-de-lure',
#  'gare-de-poligny',
#  'les-granges-narboz',
#  'jougne',
#  'marvejols-place-chayla',
#  'quillan',
#  'gare-de-meymac',
#  'mirecourt',
#  'vezelise-beauregard',
#  'mirecourt-lycee-agric',
#  'gare-de-montmedy',
#  'vezin-carrefour',
#  'gare-de-remilly',
#  'st-jean-de-bassel-eglis',
#  'sarrebourg-hopital',
#  'neufchateau-lp',
#  'laveline-d-bruy-mairie',
#  'kedange-eglise',
#  'hombourg-chapelle',
#  'saint-leonard-centre',
#  'perl-gare-db',
#  'sarre-union',
#  'sarralbe-centre',
#  'sarrebourg-abri-phalsbo',
#  'sarralbe',
#  'gare-de-revigny',
#  'gare-de-pagny-sur-moselle',
#  'gare-de-gramat',
#  'gare-de-toulouse-matabiau',
#  'gare-de-castelsarrasin',
#  'st-sulpice-sur-leze',
#  'luchon-richelieu',
#  'luchon',
#  'latour-de-carol',
#  'wambrechies',
#  'gare-de-rue',
#  'gare-de-hirson-ecoles',
#  'gare-de-lison',
#  'gare-de-pontorson-mt-st-michel',
#  'vire-centre',
#  'gare-de-flers',
#  'gare-de-briouze',
#  'gare-de-surdon',
#  'le-mont-st-michel',
#  'routot-place-de-mairie',
#  'gare-de-st-gilles-croix-de-vie',
#  'laon-gare-routiere-poma',
#  'gare-de-ribecourt',
#  'gare-de-prisse-la-charriere',
#  'valence-gare-routiere',
#  'gare-de-lyon-gorge-de-loup',
#  'lyon-st-paul-quai-bondy',
#  'grandris-centre',
#  'poule-mairie',
#  'morez-lycee',
#  'st-martin-d-heres',
#  'gare-de-pont-de-beauvoisin',
#  'gare-de-st-brieuc',
#  'gare-de-lamballe',
#  'gare-de-st-vit',
#  'gare-de-villers-les-pots',
#  'gare-de-neuilly-les-dijon',
#  'gare-de-st-rambert-en-bugey',
#  'gare-de-virieu-le-grand-belley',
#  'gare-de-macon-loche-tgv',
#  'lyon-st-paul-la-feuilee',
#  'vienne-gare-routiere',
#  'gare-de-st-pierre-d-albigny',
#  'st-pierre-de-chandieu-r',
#  'gare-de-rives',
#  'gare-de-culoz',
#  'gare-de-rumilly',
#  'ternay-barbieres',
#  'gare-de-montmelian',
#  'st-christophe-nais-c',
#  'gare-de-courtalain-st-pellerin',
#  'mondoubleau-rue-leroy',
#  'montargis-ot',
#  'sancerre-porte-cesar',
#  'nan',
#  'issoudun-place-de-la-g',
#  'issoudun-jardin',
#  'poitiers-gare-routiere',
#  'romorantin-lycee-de-f',
#  'gare-de-eguzon',
#  'st-aignan-lep',
#  'st-aignan-pl-wilson',
#  'chateauroux-charmilles',
#  'gare-de-montbazon',
#  'truyes-st-blaise',
#  'tours-lycee-grandmont',
#  'reignac-bourg-du-fau',
#  'truyes-pl-du-souvenir',
#  'gare-de-veigne',
#  'chateauroux-l-giraudoux',
#  'vierzon-mediatheque',
#  'gare-de-limeray',
#  'gare-de-dourdan',
#  'gare-de-vendome-villiers-s-loir',
#  'rambervillers-11-nov',
#  'moyen',
#  'rambervillers',
#  'gerardmer-la-mauselaine',
#  'la-bresse-pl-champtel',
#  'la-bresse-le-lispach',
#  'st-louis-57-incline',
#  'lugny',
#  'gare-de-verneuil-sur-serre',
#  'gare-de-woerth-rhein',
#  'gare-de-ventimiglia-stazione',
#  'gare-de-trier-hbf-treves',
#  'gare-de-rodange',
#  'gare-de-mullheim-baden-bf',
#  'gare-de-munster',
#  'mutzig-passage-a-niveau',
#  'gare-de-puyoo',
#  'gare-de-morcenx',
#  'gare-de-pauillac',
#  'gare-de-le-verdon',
#  'gare-de-st-jean-pied-de-port',
#  'gare-de-cambo-les-bains',
#  'gare-de-hendaye',
#  'gare-de-st-emilion',
#  'gare-de-sarlat',
#  'gare-de-langon',
#  'gare-de-vorey',
#  'gare-de-tonnerre',
#  'gare-de-les-laumes-alesia',
#  'gare-de-nevers-le-banlay',
#  'gare-de-vesoul',
#  'gare-de-vitre',
#  'gare-de-vannes',
#  'gare-de-rosporden',
#  'gare-de-morlaix',
#  'gare-de-la-forest',
#  'gare-de-toury',
#  'gare-de-chateau-gaillard',
#  'gare-de-la-verriere',
#  'gare-de-versailles-chantiers',
#  'gare-de-givet',
#  'gare-de-nouzonville',
#  'gare-de-sedan',
#  'gare-de-vauvert',
#  'gare-de-saillat-chassenon',
#  'pompadour',
#  'gare-de-pont-st-vincent',
#  'laissac-foirail',
#  'gare-de-rang-du-fl-verton-ber',
#  'gare-de-mouscron-moeskroen',
#  'gare-de-valenciennes',
#  'gare-de-st-pol-sur-ternoise',
#  'gare-de-sable-sur-sarthe',
#  'gare-de-persan-beaumont',
#  'gare-de-st-just-sncf',
#  'le-treport-mers-les-b',
#  'gare-de-saintes',
#  'gare-de-rochefort',
#  'gare-de-st-mariens-st-yzan',
#  'gare-de-toulon',
#  'gare-de-st-raphael-valescure',
#  'gare-de-sospel',
#  'gare-de-touet-de-l-escarene',
#  'gare-de-miramas',
#  'gare-de-sisteron',
#  'gare-de-martigues',
#  'gare-de-willer-sur-thur',
#  'gare-de-etaples-le-touquet',
#  'gare-de-tourcoing',
#  'gare-de-st-omer',
#  'gare-de-vernon-giverny',
#  'gare-de-montivilliers',
#  'gare-de-rolleville',
#  'gare-de-yvetot',
#  'gare-de-serquigny',
#  'normandie',
#  'gare-de-st-lo',
#  'gare-de-st-malo',
#  'gare-de-plouaret-tregor',
#  'gare-de-paimpol',
#  'gare-de-st-nazaire',
#  'gare-de-savenay',
#  'gare-de-ste-pazanne',
#  'gare-de-pornic',
#  'gare-de-suce-sur-erdre',
#  'gare-de-nort-sur-erdre',
#  'gare-de-voves',
#  'gare-de-vallon-en-sully',
#  'gare-de-coutras',
#  'gare-de-pessac',
#  'gare-de-marmande',
#  'gare-de-st-junien',
#  'gare-de-saint-cyprien-arenes',
#  'gare-de-durtol-nohanent',
#  'gare-de-le-lioran',
#  'gare-de-sete',
#  'gare-de-orange',
#  'gare-de-carpentras',
#  'gare-de-marseille-blancarde',
#  'gare-de-pierrelatte',
#  'gare-de-st-etienne-chateaucreux',
#  'gare-de-sathonay-rillieux',
#  'gare-de-tassin',
#  'gare-de-montbeliard-ville']

# %%
# get all possible itineraries from a localisation
def get_itineraries(fromLoc):
    return itineraries.loc[itineraries['start'] == fromLoc]

# %%
# update distance of localisation from source
def updateDistanceFromSource(matrix, itineraries):
    # print(itineraries)

    for index, row in itineraries.iterrows():

        # if initerary is not yet processed
        if matrix[row['end']]['processed'] == False:

            oldValue = matrix[row['end']]['distanceFromSource']
            newValue = matrix[row['start']
                              ]['distanceFromSource'] + row['duree']

            if oldValue == 'infinite':
                matrix[row['end']]['distanceFromSource'] = newValue
                matrix[row['end']]['fromLoc'] = row['start']
            else:
                if newValue < oldValue:
                    matrix[row['end']]['distanceFromSource'] = newValue
                    matrix[row['end']]['fromLoc'] = row['start']

    # print("-----------------------------------------------------------------")
    # print("---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------")
    # print("-----------------------------------------------------------------")
    # print(" ")

    return matrix

# %%
# Find the minimum distance that has not been processed and that is not infinite
def findMiniDistanceFromSource(matrix):
    
    toProcess = {}
    
    for index, row in matrix.items():
        if row['processed'] == False and row['distanceFromSource'] != 'infinite':
            toProcess[index] = row
            
    # print("-------------------- Les itineraires pas encore traités ---------------------")
    # print(" ")
    # [print(key,':',value) for key, value in toProcess.items()]
    # print(" ")
    
    miniValue = 9999999999
    location = ""
    
    for index, row in toProcess.items():
    
        if row['distanceFromSource'] < miniValue:
            miniValue = row['distanceFromSource']
            location = index
            
       
    # if location != "":    
    #     print("-------------------- La distance la plus courte pas encore traitée ---------------------")
    #     print(" ")
    #     print("Etape : ", location, " - Distance depuis la source : ", miniValue)
    #     print(" ")
    # else:
    #     print("------------------------------------------------------------------------")
    #     print("-------------------- Plus de trajets lié à traiter ---------------------")
    #     print("------------------------------------------------------------------------")
    #     print(" ")
        
    return location

# %%
# find the shortest distance between source and destination
def get_best_itinerary(matrix, source, destination):
    toProcess = {}
    distance = ""
    fromLoc = ""
    itineraries = []

    for index, row in matrix.items():
        if row['processed'] == True and row['distanceFromSource'] != 'infinite':
            toProcess[index] = row

    # print(toProcess)
    if destination in toProcess.keys():
        # print(toProcess[destination])
        distance = toProcess[destination]["distanceFromSource"]
        fromLoc = toProcess[destination]["fromLoc"]
        itineraries.insert(0, destination)

        while fromLoc != source:
            itineraries.insert(0, fromLoc)
            fromLoc = toProcess[fromLoc]["fromLoc"]

        itineraries.insert(0, source)

        return {
            'distance': distance,
            'itineraries': itineraries
        }

    else:
        print("-----------------------------------------------------------------")
        print("-------------------- Ce trajet n'existe pas ---------------------")
        print("-----------------------------------------------------------------")
        print("")

        return "None"

# %%
# Find the shortest path among all possible sources and destinations 
def dijsktra(df, source, destination):
    matrixLoc = {}
    
    locsStart = list(set(df['start'].tolist()))
    locsEnd = list(set(df['end'].tolist()))
    locs = list(dict.fromkeys(locsStart + locsEnd)) 
    
    # filter possible localisations
    locsStart = list(filter(lambda k: source in k, locs))
    locsEnd = list(filter(lambda k: destination in k, locs))
    
    # print("((((((((((((((aaa))))))))))))))")
    # print(locsStart)
    # print("((((((((((((((aaa))))))))))))))")
    # print(locsEnd)
    # print("((((((((((((((zzz))))))))))))))")
    
    allResultFound = []

    # Try to find a initerary from each train station with name searched
    for locStart in locsStart:
        matrixLoc = {}
        
        for locEnd in locsEnd:
            if locEnd == locStart:
                continue
            
            matrixLoc = {}
    
            # print("Trajet : ", locStart, " - ", locEnd)
            # print(" ")
            
            # initialize matrix
            for loc in locs:
                matrixLoc[loc] = {
                    'distanceFromSource': 'infinite',
                    'fromLoc': '',
                    'processed': False,
                }
                
            # initialize matrix source values
            matrixLoc[locStart]['distanceFromSource'] = 0
            matrixLoc[locStart]['fromLoc'] = locStart
            matrixLoc[locStart]['processed'] = True
            
            nextLocation = locStart
            
            while nextLocation != "":

                if not get_itineraries(nextLocation).empty:
                    matrixLoc = updateDistanceFromSource(matrixLoc, get_itineraries(nextLocation))
                # else:
                    # print("Aucun itinéraire en partant de ", nextLocation)
                    # print(" ")
                    
                nextLocation = findMiniDistanceFromSource(matrixLoc)

                if nextLocation != "":
                    matrixLoc[nextLocation]['processed'] = True
            
            result = get_best_itinerary(matrixLoc, locStart, locEnd)
            
            if result != "None":
                allResultFound.append(result) 


    # pprint(allResultFound)
    
    results = []
    for result in allResultFound:
        if result
        
        
        
        
    return allResultFound

# %%
def get_itinerary(df=itineraries, locArray=[]):
    locArray = [slugify(x) for x in locArray]

    fullTrip = []
    distance = 0

    while len(locArray) >= 2:
        locStart = locArray[0]
        locEnd = locArray[1]

        # print(locStart)
        # print(locEnd)

        result = dijsktra(df, locStart, locEnd)
        return result

        if result:
            fullTrip = fullTrip + result['itineraries']
            distance = distance + result['distance']
            locArray.pop(0)

        else:
            print("-----------------------------------------------------------------")
            print("---------------------- Aucun trajet trouvé ----------------------")
            print("-----------------------------------------------------------------")
            print("")

            return

    fullTrip = list(dict.fromkeys(fullTrip))

    return {
        'distance': distance,
        'itineraries': fullTrip
    }

# %%
# TODO : fix this
# Probleme supposé : les trajet inversés sont possibles dans dijtra directement au lieu de step_machin
# solution : ajouter dans le dataset directement les trajet retour inverse
# get_itinerary(itineraries, ["Paris", "Marseille"])

get_itinerary(itineraries, ["Paris", "Lyon", "Marseille"])
# get_itinerary(itineraries, ["Paris", "Lyon", "Bordeaux"])
# get_itinerary(itineraries, ["Persan-Beaumont", "RENNES"])
# get_itinerary(itineraries, ["Bordeaux", "Paris", "Lille" ])
# Out:
# [{'distance': 467,
#   'itineraries': ['gare-de-paris-austerlitz',
#                   'gare-de-bourges',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'gare-de-lyon-gorge-de-loup']},
#  {'distance': 598,
#   'itineraries': ['gare-de-paris-austerlitz',
#                   'gare-de-bourges',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'lyon-st-paul-la-feuilee']},
#  {'distance': 413,
#   'itineraries': ['gare-de-paris-austerlitz',
#                   'gare-de-bourges',
#                   'gare-de-nevers',
#                   'gare-de-lyon-perrache',
#                   'gare-de-givors-ville',
#                   'gare-de-lyon-part-dieu']},
#  {'distance': 270,
#   'itineraries': ['gare-de-paris-austerlitz',
#                   'gare-de-vierzon',
#                   'gare-de-montlucon-ville',
#                   'urcay-hotel-du-lyon-d-o']},
#  {'distance': 580,
#   'itineraries': ['gare-de-paris-austerlitz',
#                   'gare-de-bourges',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'gare-de-lyon-st-paul']},
#  {'distance': 467,
#   'itineraries': ['gare-de-paris-austerlitz',
#                   'gare-de-bourges',
#                   'gare-de-nevers',
#                   'gare-de-lyon-perrache',
#                   'gare-de-villefranche-sur-saone',
#                   'lyon-perrache-gare-rout']},
#  {'distance': 478,
#   'itineraries': ['gare-de-paris-austerlitz',
#                   'gare-de-bourges',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy']},
#  {'distance': 192,
#   'itineraries': ['gare-de-paris-austerlitz',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon']},
#  {'distance': 371,
#   'itineraries': ['gare-de-paris-austerlitz',
#                   'gare-de-bourges',
#                   'gare-de-nevers',
#                   'gare-de-lyon-perrache']},
#  {'distance': 458,
#   'itineraries': ['gare-de-paris-austerlitz',
#                   'gare-de-bourges',
#                   'gare-de-nevers',
#                   'gare-de-autun',
#                   'gare-de-etang',
#                   'gare-de-montchanin',
#                   'gare-de-chalon-sur-saone',
#                   'gare-de-macon-ville',
#                   'lyon-part-dieu-gare-rou']},
#  {'distance': 784,
#   'itineraries': ['gare-de-paris-st-lazare',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'gare-de-lyon-gorge-de-loup']},
#  {'distance': 915,
#   'itineraries': ['gare-de-paris-st-lazare',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'lyon-st-paul-la-feuilee']},
#  {'distance': 730,
#   'itineraries': ['gare-de-paris-st-lazare',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-lyon-perrache',
#                   'gare-de-givors-ville',
#                   'gare-de-lyon-part-dieu']},
#  {'distance': 587,
#   'itineraries': ['gare-de-paris-st-lazare',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-vierzon',
#                   'gare-de-montlucon-ville',
#                   'urcay-hotel-du-lyon-d-o']},
#  {'distance': 897,
#   'itineraries': ['gare-de-paris-st-lazare',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'gare-de-lyon-st-paul']},
#  {'distance': 784,
#   'itineraries': ['gare-de-paris-st-lazare',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-lyon-perrache',
#                   'gare-de-villefranche-sur-saone',
#                   'lyon-perrache-gare-rout']},
#  {'distance': 795,
#   'itineraries': ['gare-de-paris-st-lazare',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy']},
#  {'distance': 471,
#   'itineraries': ['gare-de-paris-st-lazare',
#                   'gare-de-caen',
#                   'gare-de-le-mans',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon']},
#  {'distance': 688,
#   'itineraries': ['gare-de-paris-st-lazare',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-lyon-perrache']},
#  {'distance': 775,
#   'itineraries': ['gare-de-paris-st-lazare',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-autun',
#                   'gare-de-etang',
#                   'gare-de-montchanin',
#                   'gare-de-chalon-sur-saone',
#                   'gare-de-macon-ville',
#                   'lyon-part-dieu-gare-rou']},
#  {'distance': 416,
#   'itineraries': ['gare-de-paris-bercy',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'gare-de-lyon-gorge-de-loup']},
#  {'distance': 547,
#   'itineraries': ['gare-de-paris-bercy',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'lyon-st-paul-la-feuilee']},
#  {'distance': 295,
#   'itineraries': ['gare-de-paris-bercy',
#                   'gare-de-dijon-ville',
#                   'gare-de-lyon-part-dieu']},
#  {'distance': 299,
#   'itineraries': ['gare-de-paris-bercy',
#                   'gare-de-bourges',
#                   'gare-de-st-amand-montrond-orval',
#                   'gare-de-montlucon-ville',
#                   'urcay-hotel-du-lyon-d-o']},
#  {'distance': 529,
#   'itineraries': ['gare-de-paris-bercy',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'gare-de-lyon-st-paul']},
#  {'distance': 401,
#   'itineraries': ['gare-de-paris-bercy',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'gare-de-lyon-perrache',
#                   'gare-de-villefranche-sur-saone',
#                   'lyon-perrache-gare-rout']},
#  {'distance': 427,
#   'itineraries': ['gare-de-paris-bercy',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy']},
#  {'distance': 224,
#   'itineraries': ['gare-de-paris-bercy',
#                   'gare-de-auxerre-st-gervais',
#                   'gare-de-paris-gare-de-lyon']},
#  {'distance': 305,
#   'itineraries': ['gare-de-paris-bercy',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'gare-de-lyon-perrache']},
#  {'distance': 320,
#   'itineraries': ['gare-de-paris-bercy',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'lyon-part-dieu-gare-rou']},
#  {'distance': 468,
#   'itineraries': ['gare-de-paris-est',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'gare-de-lyon-gorge-de-loup']},
#  {'distance': 599,
#   'itineraries': ['gare-de-paris-est',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'lyon-st-paul-la-feuilee']},
#  {'distance': 347,
#   'itineraries': ['gare-de-paris-est',
#                   'gare-de-dijon-ville',
#                   'gare-de-lyon-part-dieu']},
#  {'distance': 614,
#   'itineraries': ['gare-de-paris-est',
#                   'gare-de-dijon-ville',
#                   'gare-de-autun',
#                   'gare-de-nevers',
#                   'gare-de-bourges',
#                   'gare-de-st-amand-montrond-orval',
#                   'gare-de-montlucon-ville',
#                   'urcay-hotel-du-lyon-d-o']},
#  {'distance': 581,
#   'itineraries': ['gare-de-paris-est',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'gare-de-lyon-st-paul']},
#  {'distance': 453,
#   'itineraries': ['gare-de-paris-est',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'gare-de-lyon-perrache',
#                   'gare-de-villefranche-sur-saone',
#                   'lyon-perrache-gare-rout']},
#  {'distance': 479,
#   'itineraries': ['gare-de-paris-est',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy']},
#  {'distance': 345,
#   'itineraries': ['gare-de-paris-est',
#                   'gare-de-troyes',
#                   'gare-de-laroche-migennes',
#                   'gare-de-paris-gare-de-lyon']},
#  {'distance': 357,
#   'itineraries': ['gare-de-paris-est',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'gare-de-lyon-perrache']},
#  {'distance': 372,
#   'itineraries': ['gare-de-paris-est',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'lyon-part-dieu-gare-rou']},
#  {'distance': 796,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#                   'gare-de-argentan',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'gare-de-lyon-gorge-de-loup']},
#  {'distance': 927,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#                   'gare-de-argentan',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'lyon-st-paul-la-feuilee']},
#  {'distance': 742,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#                   'gare-de-argentan',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-lyon-perrache',
#                   'gare-de-givors-ville',
#                   'gare-de-lyon-part-dieu']},
#  {'distance': 599,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#                   'gare-de-argentan',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-vierzon',
#                   'gare-de-montlucon-ville',
#                   'urcay-hotel-du-lyon-d-o']},
#  {'distance': 909,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#                   'gare-de-argentan',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'gare-de-lyon-st-paul']},
#  {'distance': 796,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#                   'gare-de-argentan',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-lyon-perrache',
#                   'gare-de-villefranche-sur-saone',
#                   'lyon-perrache-gare-rout']},
#  {'distance': 807,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#                   'gare-de-argentan',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-moulins-sur-allier',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy']},
#  {'distance': 483,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#                   'gare-de-argentan',
#                   'gare-de-caen',
#                   'gare-de-le-mans',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon']},
#  {'distance': 700,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#                   'gare-de-argentan',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-lyon-perrache']},
#  {'distance': 787,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#                   'gare-de-argentan',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-nevers',
#                   'gare-de-autun',
#                   'gare-de-etang',
#                   'gare-de-montchanin',
#                   'gare-de-chalon-sur-saone',
#                   'gare-de-macon-ville',
#                   'lyon-part-dieu-gare-rou']},
#  {'distance': 415,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'gare-de-lyon-gorge-de-loup']},
#  {'distance': 546,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'lyon-st-paul-la-feuilee']},
#  {'distance': 294,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-lyon-part-dieu']},
#  {'distance': 352,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#                   'gare-de-nevers',
#                   'gare-de-bourges',
#                   'gare-de-st-amand-montrond-orval',
#                   'gare-de-montlucon-ville',
#                   'urcay-hotel-du-lyon-d-o']},
#  {'distance': 528,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'gare-de-lyon-st-paul']},
#  {'distance': 400,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'gare-de-lyon-perrache',
#                   'gare-de-villefranche-sur-saone',
#                   'lyon-perrache-gare-rout']},
#  {'distance': 426,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy']},
#  {'distance': 304,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'gare-de-lyon-perrache']},
#  {'distance': 319,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'lyon-part-dieu-gare-rou']},
#  {'distance': 626,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'gare-de-lyon-gorge-de-loup']},
#  {'distance': 757,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'lyon-st-paul-la-feuilee']},
#  {'distance': 505,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-lyon-part-dieu']},
#  {'distance': 479,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-austerlitz',
#                   'gare-de-vierzon',
#                   'gare-de-montlucon-ville',
#                   'urcay-hotel-du-lyon-d-o']},
#  {'distance': 739,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'gare-de-lyon-st-paul']},
#  {'distance': 611,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'gare-de-lyon-perrache',
#                   'gare-de-villefranche-sur-saone',
#                   'lyon-perrache-gare-rout']},
#  {'distance': 637,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy']},
#  {'distance': 211,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon']},
#  {'distance': 515,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'gare-de-lyon-perrache']},
#  {'distance': 530,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#                   'gare-de-chartres',
#                   'gare-de-voves',
#                   'gare-de-chateaudun',
#                   'gare-de-paris-gare-de-lyon',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'lyon-part-dieu-gare-rou']},
#  {'distance': 654,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#                   'gare-de-laon',
#                   'gare-de-reims',
#                   'gare-de-chaumont',
#                   'gare-de-culmont-chalindrey',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'gare-de-lyon-gorge-de-loup']},
#  {'distance': 785,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#                   'gare-de-laon',
#                   'gare-de-reims',
#                   'gare-de-chaumont',
#                   'gare-de-culmont-chalindrey',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'lyon-st-paul-la-feuilee']},
#  {'distance': 533,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#                   'gare-de-laon',
#                   'gare-de-reims',
#                   'gare-de-chaumont',
#                   'gare-de-culmont-chalindrey',
#                   'gare-de-dijon-ville',
#                   'gare-de-lyon-part-dieu']},
#  {'distance': 798,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#                   'gare-de-amiens',
#                   'gare-de-rouen-rive-droite',
#                   'gare-de-caen',
#                   'gare-de-tours',
#                   'gare-de-vierzon',
#                   'gare-de-montlucon-ville',
#                   'urcay-hotel-du-lyon-d-o']},
#  {'distance': 767,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#                   'gare-de-laon',
#                   'gare-de-reims',
#                   'gare-de-chaumont',
#                   'gare-de-culmont-chalindrey',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy',
#                   'gare-de-sain-bel',
#                   'gare-de-lyon-st-paul']},
#  {'distance': 639,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#                   'gare-de-laon',
#                   'gare-de-reims',
#                   'gare-de-chaumont',
#                   'gare-de-culmont-chalindrey',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'gare-de-lyon-perrache',
#                   'gare-de-villefranche-sur-saone',
#                   'lyon-perrache-gare-rout']},
#  {'distance': 665,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#                   'gare-de-laon',
#                   'gare-de-reims',
#                   'gare-de-chaumont',
#                   'gare-de-culmont-chalindrey',
#                   'gare-de-dijon-ville',
#                   'gare-de-montchanin',
#                   'gare-de-paray-le-monial',
#                   'gare-de-lozanne',
#                   'lyon-st-paul-quai-bondy']},
#  {'distance': 579,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#                   'gare-de-laon',
#                   'gare-de-reims',
#                   'gare-de-chaumont',
#                   'gare-de-culmont-chalindrey',
#                   'gare-de-dijon-ville',
#                   'gare-de-paris-gare-de-lyon']},
#  {'distance': 543,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#                   'gare-de-laon',
#                   'gare-de-reims',
#                   'gare-de-chaumont',
#                   'gare-de-culmont-chalindrey',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'gare-de-lyon-perrache']},
#  {'distance': 558,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#                   'gare-de-laon',
#                   'gare-de-reims',
#                   'gare-de-chaumont',
#                   'gare-de-culmont-chalindrey',
#                   'gare-de-dijon-ville',
#                   'gare-de-macon-ville',
#                   'lyon-part-dieu-gare-rou']}]
# [{'distance': 467,
#   'itineraries': ['gare-de-paris-austerlitz',
#    'gare-de-bourges',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'gare-de-lyon-gorge-de-loup']},
#  {'distance': 598,
#   'itineraries': ['gare-de-paris-austerlitz',
#    'gare-de-bourges',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'lyon-st-paul-la-feuilee']},
#  {'distance': 413,
#   'itineraries': ['gare-de-paris-austerlitz',
#    'gare-de-bourges',
#    'gare-de-nevers',
#    'gare-de-lyon-perrache',
#    'gare-de-givors-ville',
#    'gare-de-lyon-part-dieu']},
#  {'distance': 270,
#   'itineraries': ['gare-de-paris-austerlitz',
#    'gare-de-vierzon',
#    'gare-de-montlucon-ville',
#    'urcay-hotel-du-lyon-d-o']},
#  {'distance': 580,
#   'itineraries': ['gare-de-paris-austerlitz',
#    'gare-de-bourges',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'gare-de-lyon-st-paul']},
#  {'distance': 467,
#   'itineraries': ['gare-de-paris-austerlitz',
#    'gare-de-bourges',
#    'gare-de-nevers',
#    'gare-de-lyon-perrache',
#    'gare-de-villefranche-sur-saone',
#    'lyon-perrache-gare-rout']},
#  {'distance': 478,
#   'itineraries': ['gare-de-paris-austerlitz',
#    'gare-de-bourges',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy']},
#  {'distance': 192,
#   'itineraries': ['gare-de-paris-austerlitz',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon']},
#  {'distance': 371,
#   'itineraries': ['gare-de-paris-austerlitz',
#    'gare-de-bourges',
#    'gare-de-nevers',
#    'gare-de-lyon-perrache']},
#  {'distance': 458,
#   'itineraries': ['gare-de-paris-austerlitz',
#    'gare-de-bourges',
#    'gare-de-nevers',
#    'gare-de-autun',
#    'gare-de-etang',
#    'gare-de-montchanin',
#    'gare-de-chalon-sur-saone',
#    'gare-de-macon-ville',
#    'lyon-part-dieu-gare-rou']},
#  {'distance': 784,
#   'itineraries': ['gare-de-paris-st-lazare',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'gare-de-lyon-gorge-de-loup']},
#  {'distance': 915,
#   'itineraries': ['gare-de-paris-st-lazare',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'lyon-st-paul-la-feuilee']},
#  {'distance': 730,
#   'itineraries': ['gare-de-paris-st-lazare',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-lyon-perrache',
#    'gare-de-givors-ville',
#    'gare-de-lyon-part-dieu']},
#  {'distance': 587,
#   'itineraries': ['gare-de-paris-st-lazare',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-vierzon',
#    'gare-de-montlucon-ville',
#    'urcay-hotel-du-lyon-d-o']},
#  {'distance': 897,
#   'itineraries': ['gare-de-paris-st-lazare',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'gare-de-lyon-st-paul']},
#  {'distance': 784,
#   'itineraries': ['gare-de-paris-st-lazare',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-lyon-perrache',
#    'gare-de-villefranche-sur-saone',
#    'lyon-perrache-gare-rout']},
#  {'distance': 795,
#   'itineraries': ['gare-de-paris-st-lazare',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy']},
#  {'distance': 471,
#   'itineraries': ['gare-de-paris-st-lazare',
#    'gare-de-caen',
#    'gare-de-le-mans',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon']},
#  {'distance': 688,
#   'itineraries': ['gare-de-paris-st-lazare',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-lyon-perrache']},
#  {'distance': 775,
#   'itineraries': ['gare-de-paris-st-lazare',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-autun',
#    'gare-de-etang',
#    'gare-de-montchanin',
#    'gare-de-chalon-sur-saone',
#    'gare-de-macon-ville',
#    'lyon-part-dieu-gare-rou']},
#  {'distance': 416,
#   'itineraries': ['gare-de-paris-bercy',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'gare-de-lyon-gorge-de-loup']},
#  {'distance': 547,
#   'itineraries': ['gare-de-paris-bercy',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'lyon-st-paul-la-feuilee']},
#  {'distance': 295,
#   'itineraries': ['gare-de-paris-bercy',
#    'gare-de-dijon-ville',
#    'gare-de-lyon-part-dieu']},
#  {'distance': 299,
#   'itineraries': ['gare-de-paris-bercy',
#    'gare-de-bourges',
#    'gare-de-st-amand-montrond-orval',
#    'gare-de-montlucon-ville',
#    'urcay-hotel-du-lyon-d-o']},
#  {'distance': 529,
#   'itineraries': ['gare-de-paris-bercy',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'gare-de-lyon-st-paul']},
#  {'distance': 401,
#   'itineraries': ['gare-de-paris-bercy',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'gare-de-lyon-perrache',
#    'gare-de-villefranche-sur-saone',
#    'lyon-perrache-gare-rout']},
#  {'distance': 427,
#   'itineraries': ['gare-de-paris-bercy',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy']},
#  {'distance': 224,
#   'itineraries': ['gare-de-paris-bercy',
#    'gare-de-auxerre-st-gervais',
#    'gare-de-paris-gare-de-lyon']},
#  {'distance': 305,
#   'itineraries': ['gare-de-paris-bercy',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'gare-de-lyon-perrache']},
#  {'distance': 320,
#   'itineraries': ['gare-de-paris-bercy',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'lyon-part-dieu-gare-rou']},
#  {'distance': 468,
#   'itineraries': ['gare-de-paris-est',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'gare-de-lyon-gorge-de-loup']},
#  {'distance': 599,
#   'itineraries': ['gare-de-paris-est',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'lyon-st-paul-la-feuilee']},
#  {'distance': 347,
#   'itineraries': ['gare-de-paris-est',
#    'gare-de-dijon-ville',
#    'gare-de-lyon-part-dieu']},
#  {'distance': 614,
#   'itineraries': ['gare-de-paris-est',
#    'gare-de-dijon-ville',
#    'gare-de-autun',
#    'gare-de-nevers',
#    'gare-de-bourges',
#    'gare-de-st-amand-montrond-orval',
#    'gare-de-montlucon-ville',
#    'urcay-hotel-du-lyon-d-o']},
#  {'distance': 581,
#   'itineraries': ['gare-de-paris-est',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'gare-de-lyon-st-paul']},
#  {'distance': 453,
#   'itineraries': ['gare-de-paris-est',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'gare-de-lyon-perrache',
#    'gare-de-villefranche-sur-saone',
#    'lyon-perrache-gare-rout']},
#  {'distance': 479,
#   'itineraries': ['gare-de-paris-est',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy']},
#  {'distance': 345,
#   'itineraries': ['gare-de-paris-est',
#    'gare-de-troyes',
#    'gare-de-laroche-migennes',
#    'gare-de-paris-gare-de-lyon']},
#  {'distance': 357,
#   'itineraries': ['gare-de-paris-est',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'gare-de-lyon-perrache']},
#  {'distance': 372,
#   'itineraries': ['gare-de-paris-est',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'lyon-part-dieu-gare-rou']},
#  {'distance': 796,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#    'gare-de-argentan',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'gare-de-lyon-gorge-de-loup']},
#  {'distance': 927,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#    'gare-de-argentan',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'lyon-st-paul-la-feuilee']},
#  {'distance': 742,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#    'gare-de-argentan',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-lyon-perrache',
#    'gare-de-givors-ville',
#    'gare-de-lyon-part-dieu']},
#  {'distance': 599,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#    'gare-de-argentan',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-vierzon',
#    'gare-de-montlucon-ville',
#    'urcay-hotel-du-lyon-d-o']},
#  {'distance': 909,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#    'gare-de-argentan',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'gare-de-lyon-st-paul']},
#  {'distance': 796,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#    'gare-de-argentan',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-lyon-perrache',
#    'gare-de-villefranche-sur-saone',
#    'lyon-perrache-gare-rout']},
#  {'distance': 807,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#    'gare-de-argentan',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-moulins-sur-allier',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy']},
#  {'distance': 483,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#    'gare-de-argentan',
#    'gare-de-caen',
#    'gare-de-le-mans',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon']},
#  {'distance': 700,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#    'gare-de-argentan',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-lyon-perrache']},
#  {'distance': 787,
#   'itineraries': ['gare-de-paris-montp-3-vaug',
#    'gare-de-argentan',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-nevers',
#    'gare-de-autun',
#    'gare-de-etang',
#    'gare-de-montchanin',
#    'gare-de-chalon-sur-saone',
#    'gare-de-macon-ville',
#    'lyon-part-dieu-gare-rou']},
#  {'distance': 415,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'gare-de-lyon-gorge-de-loup']},
#  {'distance': 546,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'lyon-st-paul-la-feuilee']},
#  {'distance': 294,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-lyon-part-dieu']},
#  {'distance': 352,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#    'gare-de-nevers',
#    'gare-de-bourges',
#    'gare-de-st-amand-montrond-orval',
#    'gare-de-montlucon-ville',
#    'urcay-hotel-du-lyon-d-o']},
#  {'distance': 528,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'gare-de-lyon-st-paul']},
#  {'distance': 400,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'gare-de-lyon-perrache',
#    'gare-de-villefranche-sur-saone',
#    'lyon-perrache-gare-rout']},
#  {'distance': 426,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy']},
#  {'distance': 304,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'gare-de-lyon-perrache']},
#  {'distance': 319,
#   'itineraries': ['gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'lyon-part-dieu-gare-rou']},
#  {'distance': 626,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'gare-de-lyon-gorge-de-loup']},
#  {'distance': 757,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'lyon-st-paul-la-feuilee']},
#  {'distance': 505,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-lyon-part-dieu']},
#  {'distance': 479,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-austerlitz',
#    'gare-de-vierzon',
#    'gare-de-montlucon-ville',
#    'urcay-hotel-du-lyon-d-o']},
#  {'distance': 739,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'gare-de-lyon-st-paul']},
#  {'distance': 611,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'gare-de-lyon-perrache',
#    'gare-de-villefranche-sur-saone',
#    'lyon-perrache-gare-rout']},
#  {'distance': 637,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy']},
#  {'distance': 211,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon']},
#  {'distance': 515,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'gare-de-lyon-perrache']},
#  {'distance': 530,
#   'itineraries': ['gare-de-paris-montparnasse-1-2',
#    'gare-de-chartres',
#    'gare-de-voves',
#    'gare-de-chateaudun',
#    'gare-de-paris-gare-de-lyon',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'lyon-part-dieu-gare-rou']},
#  {'distance': 654,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#    'gare-de-laon',
#    'gare-de-reims',
#    'gare-de-chaumont',
#    'gare-de-culmont-chalindrey',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'gare-de-lyon-gorge-de-loup']},
#  {'distance': 785,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#    'gare-de-laon',
#    'gare-de-reims',
#    'gare-de-chaumont',
#    'gare-de-culmont-chalindrey',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'lyon-st-paul-la-feuilee']},
#  {'distance': 533,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#    'gare-de-laon',
#    'gare-de-reims',
#    'gare-de-chaumont',
#    'gare-de-culmont-chalindrey',
#    'gare-de-dijon-ville',
#    'gare-de-lyon-part-dieu']},
#  {'distance': 798,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#    'gare-de-amiens',
#    'gare-de-rouen-rive-droite',
#    'gare-de-caen',
#    'gare-de-tours',
#    'gare-de-vierzon',
#    'gare-de-montlucon-ville',
#    'urcay-hotel-du-lyon-d-o']},
#  {'distance': 767,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#    'gare-de-laon',
#    'gare-de-reims',
#    'gare-de-chaumont',
#    'gare-de-culmont-chalindrey',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy',
#    'gare-de-sain-bel',
#    'gare-de-lyon-st-paul']},
#  {'distance': 639,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#    'gare-de-laon',
#    'gare-de-reims',
#    'gare-de-chaumont',
#    'gare-de-culmont-chalindrey',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'gare-de-lyon-perrache',
#    'gare-de-villefranche-sur-saone',
#    'lyon-perrache-gare-rout']},
#  {'distance': 665,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#    'gare-de-laon',
#    'gare-de-reims',
#    'gare-de-chaumont',
#    'gare-de-culmont-chalindrey',
#    'gare-de-dijon-ville',
#    'gare-de-montchanin',
#    'gare-de-paray-le-monial',
#    'gare-de-lozanne',
#    'lyon-st-paul-quai-bondy']},
#  {'distance': 579,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#    'gare-de-laon',
#    'gare-de-reims',
#    'gare-de-chaumont',
#    'gare-de-culmont-chalindrey',
#    'gare-de-dijon-ville',
#    'gare-de-paris-gare-de-lyon']},
#  {'distance': 543,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#    'gare-de-laon',
#    'gare-de-reims',
#    'gare-de-chaumont',
#    'gare-de-culmont-chalindrey',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'gare-de-lyon-perrache']},
#  {'distance': 558,
#   'itineraries': ['gare-de-paris-gare-du-nord',
#    'gare-de-laon',
#    'gare-de-reims',
#    'gare-de-chaumont',
#    'gare-de-culmont-chalindrey',
#    'gare-de-dijon-ville',
#    'gare-de-macon-ville',
#    'lyon-part-dieu-gare-rou']}]
